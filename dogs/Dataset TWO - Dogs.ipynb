# %% [markdown]
# # Homework 7, Part Two: A dataset about dogs.
#
# Data from [a FOIL request to New York City](https://www.muckrock.com/foi/new-york-city-17/pet-licensing-data-for-new-york-city-23826/)

# %% [markdown]
# ## Do your importing and your setup

# %%
import pandas as pd

# %% [markdown]
# ## Read in the file `NYC_Dog_Licenses_Current_as_of_4-28-2016.xlsx` and look at the first five rows

# %%
df = pd.read_excel("NYC_Dog_Licenses_Current_as_of_4-28-2016.xlsx")
df.head()
# Out:
#    Owner Zip Code   Animal Name Animal Gender         Primary Breed  \
# 0           10024     BLUE MACK             M               Unknown
# 1           10461  Indie Zephir             M            Rottweiler
# 2           10013         Bilal             M  Australian Cattledog
# 3           10025         Buddy             M               Unknown
# 4           10013           Ali             M               Basenji
#
#   Secondary Breed Animal Dominant Color Animal Secondary Color  \
# 0   AIREDALE TERR                 BROWN                  BLACK
# 1             NaN                 BLACK                    TAN
# 2             NaN                  Rust                    NaN
# 3        Cockapoo                 BLOND                  WHITE
# 4             NaN                 Black                    NaN
#
#   Animal Third Color Animal Birth Spayed or Neut Guard or Trained Vaccinated  \
# 0                NaN   2007-11-01            Yes               No        Yes
# ...

# %%
# remove spaces in columns name
df.columns = df.columns.str.replace(' ','_')
df
# Out:
#        Owner_Zip_Code    Animal_Name Animal_Gender  \
# 0               10024      BLUE MACK             M
# 1               10461   Indie Zephir             M
# 2               10013          Bilal             M
# 3               10025          Buddy             M
# 4               10013            Ali             M
# ...               ...            ...           ...
# 81932           10001  Cheeseburger              M
# 81933           10021           Jack             M
# 81934           10032        Petunia             F
# 81935           10310            Max             M
# 81936           10016         Sirius             F
#
#                     Primary_Breed Secondary_Breed Animal_Dominant_Color  \
# 0                         Unknown   AIREDALE TERR                 BROWN
# 1                      Rottweiler             NaN                 BLACK
# 2            Australian Cattledog             NaN                  Rust
# ...

# %% [markdown]
# ## How many rows do you have in the data? What are the column types?
#
# If there are more than 30,000 rows in your dataset, go back and only read in the first 30,000.
#
# * *Tip: there's an option with `.read_csv` to only read in a certain number of rows*

# %%
df.shape
# Out:
# (81937, 15)

# %%
#Reading only the first 30000 rows
df= pd.read_excel("NYC_Dog_Licenses_Current_as_of_4-28-2016.xlsx",nrows = 30000)

df.shape
# Out:
# (30000, 15)

# %% [markdown]
# ## Describe the dataset in words. What is each row? List two column titles along with what each of those columns means.
#
# For example: “Each row is an animal in the zoo. `is_reptile` is whether the animal is a reptile or not”

# %%
# The dataset is about dogs.Each row has a dog name whose basic info (characteristics) like gender,primary breed name,colour

# %%
# etc. is given.Two columns are "Animal_Birth" which is the birthdate of the dog and "Vacinated" which tells whether the dog is

# %%
# is vaccinated or not.

# %% [markdown]
# # Your thoughts
#
# Think of four questions you could ask this dataset. **Don't ask them**, just write them down in the cell below. Feel free to use either Markdown or Python comments.

# %% [markdown]
# # Looking at some dogs

# %% [markdown]
# ## What are the most popular (primary) breeds of dogs? Graph the top 10.

# %%
df
# Out:
#        Owner_Zip_Code   Animal_Name Animal_Gender         Primary_Breed  \
# 0               10024     BLUE MACK             M               Unknown
# 1               10461  Indie Zephir             M            Rottweiler
# 2               10013         Bilal             M  Australian Cattledog
# 3               10025         Buddy             M               Unknown
# 4               10013           Ali             M               Basenji
# ...               ...           ...           ...                   ...
# 29995           11372         Bella             F               Unknown
# 29996           11417         Sadie             F  Schnauzer, Miniature
# 29997           11228       unknown             M            Pomeranian
# 29998           11217         daisy             F               Unknown
# 29999           10038       Squeeze             M              Shih Tzu
#
#       Secondary_Breed Animal_Dominant_Color Animal_Secondary_Color  \
# ...

# %%
# The most popular (primary) breeds of dogs

df.Primary_Breed.value_counts().head(10)
# Out:
# Unknown                                 4777
# Yorkshire Terrier                       1882
# Shih Tzu                                1760
# Chihuahua                               1535
# Maltese                                 1133
# Labrador Retriever                      1074
# American Pit Bull Terrier/Pit Bull       780
# Labrador Retriever Crossbreed            738
# American Pit Bull Mix / Pit Bull Mix     722
# Jack Russell Terrier                     553
# Name: Primary_Breed, dtype: int64

# %%
df.Primary_Breed.value_counts().head(10).plot(kind ='barh')
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## "Unknown" is a terrible breed! Graph the top 10 breeds that are NOT Unknown
#
# * *Tip: Maybe you want to go back to your `.read_csv` and use `na_values=`? Maybe not? Up to you!*

# %%
#removing the unknowns from primary breed 
df= pd.read_excel("NYC_Dog_Licenses_Current_as_of_4-28-2016.xlsx",nrows = 30000,na_values= "Unknown")


#Also removing spaces in columns name and replacing with _

df.columns = df.columns.str.replace(' ','_')

# %%
#The graph of top 10 breeds that are NOT Unknown

df.Primary_Breed.value_counts().head(10).plot(kind ='barh')
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## What are the most popular dog names?

# %%
df.Animal_Name.value_counts()

#The most popular Dog name is Max
# Out:
# UNKNOWN          203
# Max              202
# Bella            193
# Charlie          172
# Lola             146
#                 ...
# Bluno              1
# DARBY              1
# CHARLEY VIVAR      1
# TINY               1
# Squeeze            1
# Name: Animal_Name, Length: 13720, dtype: int64

# %% [markdown]
# ## Do any dogs have your name? How many dogs are named "Max," and how many are named "Maxwell"?

# %%
df[df.Animal_Name.str.contains("^Max$", na=False)].Animal_Name.value_counts()

# There are 202 dogs with the name Max
# Out:
# Max    202
# Name: Animal_Name, dtype: int64

# %%
df[df.Animal_Name.str.contains("^Maxwell$", na=False)].Animal_Name.value_counts()

#There are 11 dogs with name Maxwell
# Out:
# Maxwell    11
# Name: Animal_Name, dtype: int64

# %% [markdown]
# ## What percentage of dogs are guard dogs?

# %%
#Guard_or_Trained

df.Guard_or_Trained.value_counts(normalize = True,dropna= False)

#0.05 % of dogs are guard dogs from the sample dataframe of 30000 dogs
# Out:
# No     0.660300
# NaN    0.339133
# Yes    0.000567
# Name: Guard_or_Trained, dtype: float64

# %% [markdown]
# ## What are the actual numbers?

# %%
df.Guard_or_Trained.value_counts(dropna= False)

# There are only 17 dogs as guard dogs
# Out:
# No     19809
# NaN    10174
# Yes       17
# Name: Guard_or_Trained, dtype: int64

# %% [markdown]
# ## Wait... if you add that up, is it the same as your number of rows? Where are the other dogs???? How can we find them??????
#
# Use your `.head()` to think about it, then you'll do some magic with `.value_counts()`. Think about missing data!

# %%
#Yes,we get  the same number of rows(i.e. 30000) if we add them up.We added dropna attribute for value_counts functions as...
    # ... False so that we also get the number of dogs whose valuese for "Guard_or_Trained" were not given

# %% [markdown]
# ## Maybe fill in all of those empty "Guard or Trained" columns with "No"? Or as `NaN`?
#
# Can we make an assumption either way? Then check your result with another `.value_counts()`

# %%
# Replacing the empty "Guard or Trained" columns with No

import numpy as np

df.Guard_or_Trained = df.Guard_or_Trained.replace(np.nan,"No")

# %%
#Verifying if empty values for  "Guard or Trained" column has changed to No or not

df.Guard_or_Trained.value_counts(dropna= False)
# Out:
# No     29983
# Yes       17
# Name: Guard_or_Trained, dtype: int64

# %% [markdown]
# ## What are the top dog breeds for guard dogs?

# %%
# getting a new dataframe df_guard that contains the data for only guard dogs:-

df_guard = df[df.Guard_or_Trained == "Yes"]
df_guard
# Out:
#        Owner_Zip_Code                Animal_Name Animal_Gender  \
# 2363            10014                     Truman             M
# 2702            10014  Bojangles Swagu Rosenberg             M
# 2871            11361                    Dorofey             M
# 3065            10033                 CLARA                  F
# 3274            10301                        Mia             F
# 5231            11209                      Lilly             F
# 10082           10014                     Jasper             M
# 11897           10304                        Rox             M
# 11925           10308                   Princess             F
# 15044           10040                      Nicky             M
# 20543           11235                       graf             M
# 20851           11363                 WINSTON                M
# 26278           11211                      Urkan             M
# 27584           11336                        Teo             M
# ...

# %%
#Now getting the top dog breeds for guard dogs:-

df_guard.Primary_Breed.value_counts()

# German Shepherd Dog is the top dog breed for guard dog
# Out:
# German Shepherd Dog           3
# Poodle, Standard              1
# German Shepherd Crossbreed    1
# Labrador Retriever            1
# Doberman Pinscher             1
# Shih Tzu                      1
# Rottweiler                    1
# Golden Retriever              1
# Schnauzer, Miniature          1
# Yorkshire Terrier             1
# Name: Primary_Breed, dtype: int64

# %% [markdown]
# ## Create a new column called "year" that is the dog's year of birth
#
# The `Animal Birth` column is a datetime, so you can get the year out of it with the code `df['Animal Birth'].apply(lambda birth: birth.year)`.

# %%
#Adding a new column with birth year:-

df['year'] = df['Animal_Birth'].apply(lambda birth: birth.year)
df
# Out:
#        Owner_Zip_Code   Animal_Name Animal_Gender         Primary_Breed  \
# 0               10024     BLUE MACK             M                   NaN
# 1               10461  Indie Zephir             M            Rottweiler
# 2               10013         Bilal             M  Australian Cattledog
# 3               10025         Buddy             M                   NaN
# 4               10013           Ali             M               Basenji
# ...               ...           ...           ...                   ...
# 29995           11372         Bella             F                   NaN
# 29996           11417         Sadie             F  Schnauzer, Miniature
# 29997           11228       unknown             M            Pomeranian
# 29998           11217         daisy             F                   NaN
# 29999           10038       Squeeze             M              Shih Tzu
#
#       Secondary_Breed Animal_Dominant_Color Animal_Secondary_Color  \
# ...

# %% [markdown]
# ## Calculate a new column called “age” that shows approximately how old the dog is. How old are dogs on average?

# %%
import datetime

# %%
#We get current year with --> datetime.datetime.now().year

# %%
# calculating the approximate age of each dog  and adding it in a new column called "age"

df['age'] = datetime.datetime.now().year - df['year']
df.age
# Out:
# 0        15
# 1         9
# 2         8
# 3        14
# 4         8
#          ..
# 29995    12
# 29996    12
# 29997     8
# 29998    13
# 29999    10
# Name: age, Length: 30000, dtype: int64

# %%
# avregae age of dogs is:-
df.age.mean().round(0)

# The average age of dogs is 13 years
# Out:
# 13.0

# %% [markdown]
# # Joining data together

# %% [markdown]
# ## Which neighborhood does each dog live in?
#
# You also have a (terrible) list of NYC neighborhoods in `zipcodes-neighborhoods.csv`. Join these two datasets together, so we know what neighborhood each dog lives in. **Be sure to not read it in as `df`, or else you'll overwrite your dogs dataframe.**

# %%
# reading the csv file with zipcodes of NYC neighbourhoods.

zip_df = pd.read_csv("zipcodes-neighborhoods.csv")
zip_df
# Out:
#                  neighborhood    zip        borough
# 0               Central Bronx  10453          Bronx
# 1               Central Bronx  10457          Bronx
# 2               Central Bronx  10460          Bronx
# 3      Bronx Park and Fordham  10458          Bronx
# 4      Bronx Park and Fordham  10467          Bronx
# ..                        ...    ...            ...
# 173               South Shore  10312  Staten Island
# 174  Stapleton and St. George  10301  Staten Island
# 175  Stapleton and St. George  10304  Staten Island
# 176  Stapleton and St. George  10305  Staten Island
# 177                Mid-Island  10314  Staten Island
#
# [178 rows x 3 columns]

# %%
# Joining the two datsets together based on common zipcodes:-

merged =df.merge(zip_df,left_on = 'Owner_Zip_Code',right_on = 'zip')
merged
# Out:
#        Owner_Zip_Code Animal_Name Animal_Gender  \
# 0               10024   BLUE MACK             M
# 1               10024       Louie             M
# 2               10024       Tosha             F
# 3               10024     Poppett             F
# 4               10024      Harlen             M
# ...               ...         ...           ...
# 29568           11436        Jack             M
# 29569           11436  ROXY                   F
# 29570           11436       marco             M
# 29571           11436  Maximilian             M
# 29572           11005      Bichon             F
#
#                           Primary_Breed  Secondary_Breed  \
# 0                                   NaN    AIREDALE TERR
# 1                                   NaN        Coonhound
# 2                   Collie, Smooth Coat              NaN
# 3      Dachshund, Long Haired Miniature              NaN
# 4                                   NaN      Plott Hound
# ...

# %% [markdown]
# ## What is the most popular dog name in all parts of the Bronx? How about Brooklyn? The Upper East Side?
#
# You'll want to do these separately, and filter for each.

# %%
df_bronx = merged[merged.borough == "Bronx"]
df_bronx

df_bronx.Animal_Name.value_counts().head()


# Bella is the most popular dog name in Bronx
# Out:
# Bella       22
# Max         21
# Rocky       20
# Princess    15
# Lucky       15
# Name: Animal_Name, dtype: int64

# %%
df_brooklyn = merged[merged.borough == "Brooklyn"]
df_brooklyn

df_brooklyn.Animal_Name.value_counts().head()

# Max is the most popular dog name in Brooklyn
# Out:
# Max        46
# unknown    45
# UNKNOWN    45
# Bella      45
# Charlie    42
# Name: Animal_Name, dtype: int64

# %%
df_upper_east = merged[merged.neighborhood == "Upper East Side"]
df_upper_east

df_upper_east.Animal_Name.value_counts().head()

# Charlie is the most popular dog name in Upper East Side neighbourhood
# Out:
# Charlie    19
# Bella      12
# NO NAME    11
# Lola       10
# Lucy       10
# Name: Animal_Name, dtype: int64

# %% [markdown]
# ## What is the most common dog breed in each of the neighborhoods of NYC?
#
# * *Tip: There are a few ways to do this, and some are awful (see the "top 5 breeds in each borough" question below).*

# %%
merged.groupby('neighborhood').Primary_Breed.value_counts()
# Out:
# neighborhood  Primary_Breed
# Borough Park  Yorkshire Terrier              49
#               Maltese                        34
#               Shih Tzu                       34
#               Chihuahua                      32
#               Labrador Retriever             19
#                                              ..
# West Queens   Soft Coated Wheaten Terrier     1
#               Tibetan Spaniel                 1
#               Toy Fox Terrier                 1
#               Weimaraner                      1
#               Wire Fox Terrier                1
# Name: Primary_Breed, Length: 3987, dtype: int64

# %% [markdown]
# ## What breed of dogs are the least likely to be spayed? Male or female?
#
# * *Tip: This has a handful of interpretations, and some are easier than others. Feel free to skip it if you can't figure it out to your satisfaction.*

# %% [markdown]
# ## Make a new column called `monochrome` that is True for any animal that only has black, white or grey as one of its colors. How many animals are monochrome?

# %%
#Animal_Dominant_Color

df['monochrome'] = df.where(df['Animal_Dominant_Color'] == 'Black',True,False)

df
#df['hasimage'] = np.where(df['photos']!= '[]', True, False)
#df.head()
# Out:
# C:\Users\VINEET\AppData\Local\Temp\ipykernel_24264\1453155916.py:3: FutureWarning: In a future version of pandas all arguments of DataFrame.where except for the arguments 'cond' and 'other' will be keyword-only.
#   merged['monochrome'] = merged.where(merged['Animal_Dominant_Color'] == 'Black',True,False)
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\scoop\apps\pyenv\current\pyenv-win\versions\3.10.3\lib\site-packages\pandas\core\indexes\base.py:3621, in Index.get_loc(self, key, method, tolerance)
#    3620 try:
# -> 3621     return self._engine.get_loc(casted_key)
#    3622 except KeyError as err:
#
# File ~\scoop\apps\pyenv\current\pyenv-win\versions\3.10.3\lib\site-packages\pandas\_libs\index.pyx:136, in pandas._libs.index.IndexEngine.get_loc()
#
# ...

# %% [markdown]
# ## How many dogs are in each borough? Plot it in a graph.

# %%
# The number of dogs in each borough can be calculated with the following code:-

merged.groupby(['borough'])['borough'].count().sort_values(ascending =False)
# Out:
# borough
# Manhattan        10478
# Brooklyn          7466
# Queens            6154
# Bronx             2748
# Staten Island     2727
# Name: borough, dtype: int64

# %% [markdown]
# ## Which borough has the highest number of dogs per-capita?
#
# You’ll need to merge in `population_boro.csv`

# %%
# reading the csv file with population by borough.

pop_df = pd.read_csv("boro_population.csv")
pop_df
# Out:
#          borough  population  area_sqmi
# 0      Manhattan     1644518         23
# 1          Bronx     1455444         42
# 2       Brooklyn     2636735         71
# 3         Queens     2339150        109
# 4  Staten Island      474558         59

# %%
merged = pd.merge(merged,pop_df,on = 'borough')
merged
# Out:
#        Owner_Zip_Code Animal_Name Animal_Gender  \
# 0               10024   BLUE MACK             M
# 1               10024       Louie             M
# 2               10024       Tosha             F
# 3               10024     Poppett             F
# 4               10024      Harlen             M
# ...               ...         ...           ...
# 29568           11436        Jack             M
# 29569           11436  ROXY                   F
# 29570           11436       marco             M
# 29571           11436  Maximilian             M
# 29572           11005      Bichon             F
#
#                           Primary_Breed  Secondary_Breed  \
# 0                                   NaN    AIREDALE TERR
# 1                                   NaN        Coonhound
# 2                   Collie, Smooth Coat              NaN
# 3      Dachshund, Long Haired Miniature              NaN
# 4                                   NaN      Plott Hound
# ...

# %%
# calculating dogs per capita:-

d = merged.groupby(['borough'])['borough'].count().sort_values(ascending =False)

# %% [markdown]
# ## Make a bar graph of the top 5 breeds in each borough.
#
# How do you groupby and then only take the top X number? You **really** should ask me, because it's kind of crazy.
